# %% [markdown]
# # Step 1: Setting Up the Python Application

# %%
# !pip install lancedb pylance langchain langchain-openai pandas
# Out:
# Requirement already satisfied: lancedb in ./.env/lib/python3.13/site-packages (0.21.0)
# Requirement already satisfied: pylance in ./.env/lib/python3.13/site-packages (0.24.1)
# Requirement already satisfied: langchain in ./.env/lib/python3.13/site-packages (0.3.20)
# Requirement already satisfied: langchain-openai in ./.env/lib/python3.13/site-packages (0.3.8)
# Requirement already satisfied: pandas in ./.env/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: deprecation in ./.env/lib/python3.13/site-packages (from lancedb) (2.1.0)
# Requirement already satisfied: tqdm>=4.27.0 in ./.env/lib/python3.13/site-packages (from lancedb) (4.67.1)
# Requirement already satisfied: pyarrow>=14 in ./.env/lib/python3.13/site-packages (from lancedb) (19.0.1)
# Requirement already satisfied: pydantic>=1.10 in ./.env/lib/python3.13/site-packages (from lancedb) (2.10.6)
# Requirement already satisfied: packaging in ./.env/lib/python3.13/site-packages (from lancedb) (24.2)
# Requirement already satisfied: overrides>=0.7 in ./.env/lib/python3.13/site-packages (from lancedb) (7.7.0)
# Requirement already satisfied: numpy>=1.22 in ./.env/lib/python3.13/site-packages (from pylance) (2.2.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in ./.env/lib/python3.13/site-packages (from langchain) (0.3.43)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in ./.env/lib/python3.13/site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in ./.env/lib/python3.13/site-packages (from langchain) (0.3.13)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.env/lib/python3.13/site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in ./.env/lib/python3.13/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./.env/lib/python3.13/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in ./.env/lib/python3.13/site-packages (from langchain-openai) (1.65.5)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./.env/lib/python3.13/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.env/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.env/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.env/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in ./.env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.env/lib/python3.13/site-packages (from pydantic>=1.10->lancedb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./.env/lib/python3.13/site-packages (from pydantic>=1.10->lancedb) (2.27.2)
# Requirement already satisfied: six>=1.5 in ./.env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: regex>=2022.1.18 in ./.env/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: httpcore==1.* in ./.env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.env/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.env/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (3.0.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os

from langchain_openai import ChatOpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate

from pydantic import BaseModel

import lancedb
from lancedb.embeddings import get_registry
from lancedb.pydantic import LanceModel, Vector
from lancedb.embeddings import get_registry

import pandas as pd

import textwrap

# %%
os.environ["OPENAI_API_KEY"] = "voc-315507027126677388591167c58e9cc285a6.52708711"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# Set to true to give custom answers to user preference questions.
INTERACTIVE = False

# %%
# Setup LLM
llm = ChatOpenAI(model="gpt-3.5-turbo", 
             openai_api_key=os.getenv('OPENAI_API_KEY'),
             temperature=1.0, 
             max_tokens=3000)

# %%
# Setup Vector Database
vector_db = lancedb.connect(
  uri="./lancedb"
)

# %% [markdown]
# # Step 2: Generating Real Estate Listings

# %%
class Listing(BaseModel):
    neighborhood: str
    price: int
    bedrooms: int
    bathrooms: int
    house_size: int
    description: str
    neighborhood_description: str    

parser = PydanticOutputParser(pydantic_object=Listing)

# %%
# Build prompt to create fake real estate listings
example_listing = """
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

PROMPT_TEMPLATE = """You are a real estate agent, who wants to create compelling real estate listings, clients are not able to resist.

Here is an example of the information a listing:

{example}

---

{format_instructions}
"""

system_prompt = PromptTemplate.from_template(PROMPT_TEMPLATE, partial_variables={'example': example_listing, 'format_instructions':parser.get_format_instructions}).format()
human_prompt = """
    Create 10 listings as JSON array.
"""

messages = [
    ("system", system_prompt),
    ("human", human_prompt),
]

# %%
#Send Prompt to LLM to retrieve listings.
response = llm.invoke(messages)
response
# Out:
# AIMessage(content='```json\n[\n    {\n        "neighborhood": "Green Oaks",\n        "price": 800000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2000,\n        "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",\n        "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."\n    },\n    {\n        "neighborhood": "Sunnydale Estates",\n        "price": 950000,\n        "bedrooms": 4,\n        "bathrooms": 3,\n        "house_size": 2800,\n        "description": "Discover luxury living in the prestigious Sunnydale Estates. This exquisite 4-bedroom, 3-bathroom home features high-end finishes, a gourmet kitchen, and a stylish master suite. The spacious backyard is perfect for entertaining guests or simply enjoying the serene surroundings. Indulge in upscale living in Sunnydale Estates.",\n        "neighborhood_description": "Sunnydale Estates is an upscale neighborhood known for its upscale properties and well-maintained parks. Enjoy easy access to high-end shopping, fine dining restaurants, and exclusive country clubs. Experience the epitome of luxury living in Sunnydale Estates."\n    },\n    {\n        "neighborhood": "Lakeview Heights",\n        "price": 720000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2200,\n        "description": "Immerse yourself in the beauty of Lakeview Heights. This stunning 3-bedroom, 2-bathroom home offers breathtaking lake views, a modern kitchen, and a cozy fireplace. The spacious deck is perfect for enjoying the sunset or hosting a summer barbecue. Live the lakefront lifestyle in Lakeview Heights.",\n        "neighborhood_description": "Lakeview Heights is a picturesque community surrounded by crystal-clear lakes and lush greenery. Residents can enjoy water sports, hiking trails, and waterfront dining. Explore the natural beauty of Lakeview Heights right at your doorstep."\n    },\n    {\n        "neighborhood": "Golden Pines",\n        "price": 680000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 1900,\n        "description": "Experience the tranquility of Golden Pines. This cozy 3-bedroom, 2-bathroom home features a bright and airy living space, a fully equipped kitchen, and a private backyard oasis. Enjoy the peaceful surroundings and the convenience of nearby hiking trails and nature reserves. Embrace a laid-back lifestyle in Golden Pines.",\n        "neighborhood_description": "Golden Pines is a nature lover\'s paradise with sprawling forests, scenic trails, and wildlife habitats. Residents can explore the great outdoors, go birdwatching, or simply relax in the midst of nature. Discover the serenity of Golden Pines."\n    },\n    {\n        "neighborhood": "Riverfront Terrace",\n        "price": 1050000,\n        "bedrooms": 5,\n        "bathrooms": 4,\n        "house_size": 3500,\n        "description": "Live in luxury at Riverfront Terrace. This expansive 5-bedroom, 4-bathroom home offers panoramic river views, a modern chef\'s kitchen, and a spa-like master suite. The lush backyard features a swimming pool, a hot tub, and a built-in barbecue area, perfect for outdoor entertaining. Indulge in the lavish lifestyle of Riverfront Terrace.",\ ...

# %%
# Remove potential json markdown from listing
listing_json = response.content.strip('` \n')

if listing_json.startswith('json'):
    listing_json = listing_json[4:]

listing_json
# Out:
# '\n[\n    {\n        "neighborhood": "Green Oaks",\n        "price": 800000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2000,\n        "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",\n        "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."\n    },\n    {\n        "neighborhood": "Sunnydale Estates",\n        "price": 950000,\n        "bedrooms": 4,\n        "bathrooms": 3,\n        "house_size": 2800,\n        "description": "Discover luxury living in the prestigious Sunnydale Estates. This exquisite 4-bedroom, 3-bathroom home features high-end finishes, a gourmet kitchen, and a stylish master suite. The spacious backyard is perfect for entertaining guests or simply enjoying the serene surroundings. Indulge in upscale living in Sunnydale Estates.",\n        "neighborhood_description": "Sunnydale Estates is an upscale neighborhood known for its upscale properties and well-maintained parks. Enjoy easy access to high-end shopping, fine dining restaurants, and exclusive country clubs. Experience the epitome of luxury living in Sunnydale Estates."\n    },\n    {\n        "neighborhood": "Lakeview Heights",\n        "price": 720000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2200,\n        "description": "Immerse yourself in the beauty of Lakeview Heights. This stunning 3-bedroom, 2-bathroom home offers breathtaking lake views, a modern kitchen, and a cozy fireplace. The spacious deck is perfect for enjoying the sunset or hosting a summer barbecue. Live the lakefront lifestyle in Lakeview Heights.",\n        "neighborhood_description": "Lakeview Heights is a picturesque community surrounded by crystal-clear lakes and lush greenery. Residents can enjoy water sports, hiking trails, and waterfront dining. Explore the natural beauty of Lakeview Heights right at your doorstep."\n    },\n    {\n        "neighborhood": "Golden Pines",\n        "price": 680000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 1900,\n        "description": "Experience the tranquility of Golden Pines. This cozy 3-bedroom, 2-bathroom home features a bright and airy living space, a fully equipped kitchen, and a private backyard oasis. Enjoy the peaceful surroundings and the convenience of nearby hiking trails and nature reserves. Embrace a laid-back lifestyle in Golden Pines.",\n        "neighborhood_description": "Golden Pines is a nature lover\'s paradise with sprawling forests, scenic trails, and wildlife habitats. Residents can explore the great outdoors, go birdwatching, or simply relax in the midst of nature. Discover the serenity of Golden Pines."\n    },\n    {\n        "neighborhood": "Riverfront Terrace",\n        "price": 1050000,\n        "bedrooms": 5,\n        "bathrooms": 4,\n        "house_size": 3500,\n        "description": "Live in luxury at Riverfront Terrace. This expansive 5-bedroom, 4-bathroom home offers panoramic river views, a modern chef\'s kitchen, and a spa-like master suite. The lush backyard features a swimming pool, a hot tub, and a built-in barbecue area, perfect for outdoor entertaining. Indulge in the lavish lifestyle of Riverfront Terrace.",\n        "neighborhood_de ...

# %%
# Write listings as JSON to file
f = open('listings.json', 'w')
f.write(listing_json.strip())
f.close()

# %% [markdown]
# # Step 3: Storing Listings in a Vector Database

# %%
func = get_registry().get("openai").create(base_url=os.getenv('OPENAI_API_BASE'))

class ListingVector(LanceModel):
    neighborhood: str
    price: int
    bedrooms: int
    bathrooms: int
    house_size: int
    description: str = func.SourceField()
    description_vector: Vector(func.ndims()) = func.VectorField()

# %%
# Read listings from file
df = pd.read_json("listings.json")
df
# Out:
#           neighborhood    price  bedrooms  bathrooms  house_size  \
# 0           Green Oaks   800000         3          2        2000
# 1    Sunnydale Estates   950000         4          3        2800
# 2     Lakeview Heights   720000         3          2        2200
# 3         Golden Pines   680000         3          2        1900
# 4   Riverfront Terrace  1050000         5          4        3500
# 5       Mountain Ridge   890000         4          3        2700
# 6         Sunset Hills   780000         3          2        2100
# 7          Harbor View   950000         4          3        2600
# 8  Meadowbrook Estates   720000         3          2        2000
# 9          Maple Grove   670000         3          2        1900
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Discover luxury living in the prestigious Sunn...
# 2  Immerse yourself in the beauty of Lakeview Hei...
# 3  Experience the tranquility of Golden Pines. Th...
# 4  Live in luxury at Riverfront Terrace. This exp...
# 5  Escape to the serenity of Mountain Ridge. This...
# 6  Enjoy the sunset views from Sunset Hills. This...
# 7  Wake up to breathtaking harbor views in Harbor...
# 8  Step into the elegance of Meadowbrook Estates....
# 9  Find your sanctuary in Maple Grove. This invit...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnydale Estates is an upscale neighborhood k...
# 2  Lakeview Heights is a picturesque community su...
# 3  Golden Pines is a nature lover's paradise with...
# 4  Riverfront Terrace is an exclusive waterfront ...
# 5  Mountain Ridge is a peaceful mountain communit...
# 6  Sunset Hills is a friendly community known for...
# 7  Harbor View is a coveted seaside community kno...
# 8  Meadowbrook Estates is an upscale community kn...
# 9  Maple Grove is a family-friendly neighborhood ...

# %%
# Write listings to database

vector_data = df.apply(lambda listing: {
    "neighborhood": listing["neighborhood"],
    "price": listing["price"],
    "bedrooms": listing["bedrooms"],
    "bathrooms": listing["bathrooms"],
    "house_size": listing["house_size"],
    "description": listing["description"] + " " + listing["neighborhood_description"]
}, axis=1).values.tolist()

table = vector_db.create_table('listings', mode='overwrite', exist_ok=True, schema=ListingVector)
table.add(vector_data)

table.to_pandas()
# Out:
#           neighborhood    price  bedrooms  bathrooms  house_size  \
# 0           Green Oaks   800000         3          2        2000
# 1    Sunnydale Estates   950000         4          3        2800
# 2     Lakeview Heights   720000         3          2        2200
# 3         Golden Pines   680000         3          2        1900
# 4   Riverfront Terrace  1050000         5          4        3500
# 5       Mountain Ridge   890000         4          3        2700
# 6         Sunset Hills   780000         3          2        2100
# 7          Harbor View   950000         4          3        2600
# 8  Meadowbrook Estates   720000         3          2        2000
# 9          Maple Grove   670000         3          2        1900
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Discover luxury living in the prestigious Sunn...
# 2  Immerse yourself in the beauty of Lakeview Hei...
# 3  Experience the tranquility of Golden Pines. Th...
# 4  Live in luxury at Riverfront Terrace. This exp...
# 5  Escape to the serenity of Mountain Ridge. This...
# 6  Enjoy the sunset views from Sunset Hills. This...
# 7  Wake up to breathtaking harbor views in Harbor...
# 8  Step into the elegance of Meadowbrook Estates....
# 9  Find your sanctuary in Maple Grove. This invit...
#
#                                   description_vector
# 0  [0.012680263, -0.000397279, 0.0059024305, -0.0...
# 1  [0.03086828, 0.002924329, 0.013881516, -0.0266...
# 2  [0.012345566, 0.006913517, 0.019489534, -0.016...
# 3  [0.031288713, -0.005780893, 0.009240195, -0.01...
# 4  [0.0037524728, 0.004762754, -0.00031550307, -0...
# 5  [0.008170463, 0.013568463, -0.015446584, -0.00...
# 6  [0.02806657, 0.0152901905, 0.0013127859, -0.02...
# 7  [0.007002868, -0.004306897, 0.021714218, -0.01...
# 8  [-0.0025120673, -0.00090990844, -0.00085263, -...
# 9  [0.015432407, 0.013707832, 0.0016072782, -0.01...

# %% [markdown]
# # Step 4: Building the User Preference Interface

# %%
# Example
questions = [   
    "How big do you want your house to be?",
    "What are 3 most important things for you in choosing this property?", 
    "Which amenities would you like?", 
    "Which transportation options are important to you?",
    "How urban do you want your neighborhood to be?",   
]
answers = [
    "A comfortable three-bedroom house with a spacious kitchen and a cozy living room.",
    "A quiet neighborhood, good local schools, and convenient shopping options.",
    "A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system.",
    "Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads.",
    "A balance between suburban tranquility and access to urban amenities like restaurants and theaters."
]

qa_messages = []
qa_messages.append(("system", f"""
    You are a real estate preference retrieving chat bot.
    You are asking users {len(questions)} questions and they respond to it.
    
    After the last question process the given preferences and return a JSON object with keys and values containing the preferences.
    If there are concrete numbers given return them as integer field in the object, e.g. number of bedrooms = 2.
"""))

for i in range(len(questions)):
    qa_messages.append(("ai", questions[i]))
    
    # If INTERACTIVE is true, ask the user his preferences.
    if INTERACTIVE:
        qa_messages.append(("human", input(questions[i] + "\n")))
    else:
        qa_messages.append(("human", answers[i]))

qa_response = llm.invoke(qa_messages)

# %%
# Remove potential JSON markdown from response
user_preferences = qa_response.content.strip('` \n')

if user_preferences.startswith('json'):
    user_preferences = user_preferences[4:]

print(user_preferences)
# Out:
# {
#     "House Size": "Comfortable three-bedroom",
#     "Important Factors": ["Quiet neighborhood", "Good local schools", "Convenient shopping options"],
#     "Amenities": ["Backyard for gardening", "Two-car garage", "Modern, energy-efficient heating system"],
#     "Transportation Options": ["Easy access to a reliable bus line", "Proximity to a major highway", "Bike-friendly roads"],
#     "Urban Preference": "Balanced between suburban tranquility and access to urban amenities"
# }

# %% [markdown]
# # Step 5: Searching Based on Preferences

# %%
def search_listings(user_preferences, limit):
    return table.search(user_preferences).limit(limit).to_pydantic(ListingVector)

# Search for the 5 best matches of listings to user preferences
matched_listings = search_listings(user_preferences, 5)

matched_listings
# Out:
# [ListingVector(neighborhood='Maple Grove', price=670000, bedrooms=3, bathrooms=2, house_size=1900, description="Find your sanctuary in Maple Grove. This inviting 3-bedroom, 2-bathroom home features a cozy living room, a sunlit kitchen, and a landscaped backyard with mature trees. The covered porch is perfect for sipping morning coffee or enjoying the peaceful surroundings. Relax and unwind in the tranquility of Maple Grove. Maple Grove is a family-friendly neighborhood with top-rated schools, parks, and community events. Residents can enjoy picnics in the park, nature walks, and local farmers' markets. Experience the charm and sense of community in Maple Grove.", description_vector=FixedSizeList(dim=1536)),
#  ListingVector(neighborhood='Green Oaks', price=800000, bedrooms=3, bathrooms=2, house_size=2000, description='Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem. Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.', description_vector=FixedSizeList(dim=1536)),
#  ListingVector(neighborhood='Sunset Hills', price=780000, bedrooms=3, bathrooms=2, house_size=2100, description='Enjoy the sunset views from Sunset Hills. This charming 3-bedroom, 2-bathroom home features a bright and open floor plan, a cozy fireplace, and a private backyard retreat. The covered patio is ideal for al fresco dining or relaxing with a good book. Experience the warmth and charm of Sunset Hills. Sunset Hills is a friendly community known for its stunning sunsets, tree-lined streets, and family-friendly atmosphere. Residents can enjoy community events, playgrounds, and local markets. Discover the beauty of Sunset Hills.', description_vector=FixedSizeList(dim=1536)),
#  ListingVector(neighborhood='Sunnydale Estates', price=950000, bedrooms=4, bathrooms=3, house_size=2800, description='Discover luxury living in the prestigious Sunnydale Estates. This exquisite 4-bedroom, 3-bathroom home features high-end finishes, a gourmet kitchen, and a stylish master suite. The spacious backyard is perfect for entertaining guests or simply enjoying the serene surroundings. Indulge in upscale living in Sunnydale Estates. Sunnydale Estates is an upscale neighborhood known for its upscale properties and well-maintained parks. Enjoy easy access to high-end shopping, fine dining restaurants, and exclusive country clubs. Experience the epitome of luxury living in Sunnydale Estates.', description_vector=FixedSizeList(dim=1536)),
#  ListingVector(neighborhood='Golden Pines', price=680000, bedrooms=3, bathrooms=2, house_size=1900, description="Experience the tranquility of Golden Pines. This cozy 3-bedroom, 2-bathroom home features a bright and airy living space, a fully equipped kitchen, and a private backyard oasis. Enjoy the peaceful surroundings and the convenience of nearby hiking trails and nature reserves. Embrace a laid-back lifestyle in Golden Pines. Golden Pines is a nature lover's paradise with sprawling forests, scenic trails, and wildlife habitats. Residents can explore the great outdoors, go birdwatching, or simply relax in the midst of nature. Discover the serenity of Golden Pines.", description_vector=FixedSizeList(dim=1536))]

# %% [markdown]
# # Step 6: Personalizing Listing Descriptions

# %%
def personalize_listing(listing, user_preferences):

    # Create personalized listing descriptions for the found listing.
    PROMPT_TEMPLATE = """
    Take the following Listing:

    {listing}

    ---

    Without changing factual information, augment this real estate listing to highlight aspects relevant to the buyer preferences:

    {user_preferences}
    """

    prompt = PromptTemplate.from_template(PROMPT_TEMPLATE).format(user_preferences=user_preferences,listing=listing.description)
    personalized_listing = listing.model_copy()
    personalized_listing.description = llm.invoke(prompt).content
    return personalized_listing

# %%
personalized_listings = []
for listing in matched_listings:
    personalized_listing = personalize_listing(listing, user_preferences)
    personalized_listings.append(personalized_listing)

# %%
pd.DataFrame([listing.model_dump() for listing in personalized_listings])
# Out:
#         neighborhood   price  bedrooms  bathrooms  house_size  \
# 0        Maple Grove  670000         3          2        1900
# 1         Green Oaks  800000         3          2        2000
# 2       Sunset Hills  780000         3          2        2100
# 3  Sunnydale Estates  950000         4          3        2800
# 4       Golden Pines  680000         3          2        1900
#
#                                          description  \
# 0  Find your sanctuary in Maple Grove. This comfo...
# 1  Welcome to this eco-friendly oasis nestled in ...
# 2  Enjoy the sunset views from Sunset Hills. This...
# 3  Discover luxury living in the prestigious Sunn...
# 4  Experience the tranquility and convenience of ...
#
#                                   description_vector
# 0  [0.015432407148182392, 0.013707832433283329, 0...
# 1  [0.012680263258516788, -0.00039727898547425866...
# 2  [0.028066569939255714, 0.01529019046574831, 0....
# 3  [0.030868280678987503, 0.002924328902736306, 0...
# 4  [0.031288713216781616, -0.005780892912298441, ...

# %%
# Logic for Searching and Augmenting Listing Descriptions
print("User preferences:\n")
print(user_preferences)

# Find the top listing
matched_listings = search_listings(user_preferences, 1)
    
if matched_listings:
    top_listing = matched_listings[0]
    
    print("Top matching listing without augmentation:\n")
    print(f"\tNeighborhood: {top_listing.neighborhood}")
    print(f"\tPrice: ${top_listing.price}")
    print(f"\tBedrooms: {top_listing.bedrooms}")
    print(f"\tBathrooms: {top_listing.bathrooms}")
    print(f"\tHouse Size: {top_listing.house_size} sqft")
    print(f"\tDescription:\n{textwrap.fill(top_listing.description, width=70, initial_indent='\t\t', subsequent_indent='\t\t')}\n")

    personalized_listing = personalize_listing(top_listing, user_preferences)

    print("Top matching listing with augmentation:\n")
    print(f"\tNeighborhood: {personalized_listing.neighborhood}")
    print(f"\tPrice: ${personalized_listing.price}")
    print(f"\tBedrooms: {personalized_listing.bedrooms}")
    print(f"\tBathrooms: {personalized_listing.bathrooms}")
    print(f"\tHouse Size: {personalized_listing.house_size} sqft")
    print(f"\tDescription:\n{textwrap.fill(personalized_listing.description, width=70, initial_indent='\t\t', subsequent_indent='\t\t')}\n")
else:
    print("No relevant listings found.")
# Out:
# User preferences:
#
# {
#     "House Size": "Comfortable three-bedroom",
#     "Important Factors": ["Quiet neighborhood", "Good local schools", "Convenient shopping options"],
#     "Amenities": ["Backyard for gardening", "Two-car garage", "Modern, energy-efficient heating system"],
#     "Transportation Options": ["Easy access to a reliable bus line", "Proximity to a major highway", "Bike-friendly roads"],
#     "Urban Preference": "Balanced between suburban tranquility and access to urban amenities"
# }
# Top matching listing without augmentation:
#
# 	Neighborhood: Maple Grove
# 	Price: $670000
# 	Bedrooms: 3
# 	Bathrooms: 2
# 	House Size: 1900 sqft
# 	Description:
# 		Find your sanctuary in Maple Grove. This inviting 3-bedroom,
# 		2-bathroom home features a cozy living room, a sunlit kitchen, and a
# 		landscaped backyard with mature trees. The covered porch is perfect
# 		for sipping morning coffee or enjoying the peaceful surroundings.
# 		Relax and unwind in the tranquility of Maple Grove. Maple Grove is a
# 		family-friendly neighborhood with top-rated schools, parks, and
# 		community events. Residents can enjoy picnics in the park, nature
# 		walks, and local farmers' markets. Experience the charm and sense of
# 		community in Maple Grove.
#
# Top matching listing with augmentation:
#
# 	Neighborhood: Maple Grove
# 	Price: $670000
# 	Bedrooms: 3
# 	Bathrooms: 2
# 	House Size: 1900 sqft
# 	Description:
# 		Find your sanctuary in Maple Grove. This comfortable three-bedroom,
# 		two-bathroom home is located in a quiet neighborhood with good local
# 		schools and convenient shopping options nearby. The inviting living
# 		room and sunlit kitchen provide a cozy atmosphere, while the
# 		landscaped backyard with mature trees is perfect for gardening
# 		enthusiasts. The covered porch is ideal for sipping morning coffee
# 		in peace and tranquility.   In addition, this home features a two-
# 		car garage and a modern, energy-efficient heating system. Residents
# 		can easily access a reliable bus line, major highway, and bike-
# 		friendly roads, making transportation options a breeze. Maple Grove
# 		offers a perfect balance between suburban tranquility and access to
# 		urban amenities, with picnics in the park, nature walks, and local
# 		farmers' markets just a short distance away. Experience the charm
# 		and sense of community in Maple Grove.
