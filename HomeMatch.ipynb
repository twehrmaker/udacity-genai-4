# %% [markdown]
# # Step 1: Setting Up the Python Application

# %%
# !pip install lancedb pylance langchain langchain-openai pandas
# Out:
# Requirement already satisfied: lancedb in ./.env/lib/python3.13/site-packages (0.21.0)
# Requirement already satisfied: pylance in ./.env/lib/python3.13/site-packages (0.24.1)
# Requirement already satisfied: langchain in ./.env/lib/python3.13/site-packages (0.3.20)
# Requirement already satisfied: langchain-openai in ./.env/lib/python3.13/site-packages (0.3.8)
# Requirement already satisfied: pandas in ./.env/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: deprecation in ./.env/lib/python3.13/site-packages (from lancedb) (2.1.0)
# Requirement already satisfied: tqdm>=4.27.0 in ./.env/lib/python3.13/site-packages (from lancedb) (4.67.1)
# Requirement already satisfied: pyarrow>=14 in ./.env/lib/python3.13/site-packages (from lancedb) (19.0.1)
# Requirement already satisfied: pydantic>=1.10 in ./.env/lib/python3.13/site-packages (from lancedb) (2.10.6)
# Requirement already satisfied: packaging in ./.env/lib/python3.13/site-packages (from lancedb) (24.2)
# Requirement already satisfied: overrides>=0.7 in ./.env/lib/python3.13/site-packages (from lancedb) (7.7.0)
# Requirement already satisfied: numpy>=1.22 in ./.env/lib/python3.13/site-packages (from pylance) (2.2.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in ./.env/lib/python3.13/site-packages (from langchain) (0.3.43)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in ./.env/lib/python3.13/site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in ./.env/lib/python3.13/site-packages (from langchain) (0.3.13)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.env/lib/python3.13/site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in ./.env/lib/python3.13/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./.env/lib/python3.13/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in ./.env/lib/python3.13/site-packages (from langchain-openai) (1.65.5)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./.env/lib/python3.13/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.env/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.env/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.env/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in ./.env/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.env/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in ./.env/lib/python3.13/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.env/lib/python3.13/site-packages (from pydantic>=1.10->lancedb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./.env/lib/python3.13/site-packages (from pydantic>=1.10->lancedb) (2.27.2)
# Requirement already satisfied: six>=1.5 in ./.env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: regex>=2022.1.18 in ./.env/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: httpcore==1.* in ./.env/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.env/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.env/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (3.0.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os

from langchain_openai import ChatOpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate

from pydantic import BaseModel

import lancedb
from lancedb.embeddings import get_registry
from lancedb.pydantic import LanceModel, Vector
from lancedb.embeddings import get_registry

import pandas as pd

# %%
os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# Set to true to give custom answers to user preference questions.
INTERACTIVE = False

# %%
# Setup LLM
llm = ChatOpenAI(model="gpt-3.5-turbo", 
             openai_api_key=os.getenv('OPENAI_API_KEY'),
             temperature=1.0, 
             max_tokens=3000)

# %%
# Setup Vector Database
vector_db = lancedb.connect(
  uri="./lancedb"
)

# %% [markdown]
# # Step 2: Generating Real Estate Listings

# %%
class Listing(BaseModel):
    neighborhood: str
    price: int
    bedrooms: int
    bathrooms: int
    house_size: int
    description: str
    neighborhood_description: str    

parser = PydanticOutputParser(pydantic_object=Listing)

# %%
# Build prompt to create fake real estate listings
example_listing = """
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

PROMPT_TEMPLATE = """You are a real estate agent, who wants to create compelling real estate listings, clients are not able to resist.

Here is an example of the information a listing:

{example}

---

{format_instructions}
"""

system_prompt = PromptTemplate.from_template(PROMPT_TEMPLATE, partial_variables={'example': example_listing, 'format_instructions':parser.get_format_instructions}).format()
human_prompt = """
    Create 10 listings as JSON array.
"""

messages = [
    ("system", system_prompt),
    ("human", human_prompt),
]

# %%
#Send Prompt to LLM to retrieve listings.
response = llm.invoke(messages)
response
# Out:
# AIMessage(content='```json\n[\n    {\n        "neighborhood": "Green Oaks",\n        "price": 800000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2000,\n        "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",\n        "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."\n    },\n    {\n        "neighborhood": "Maple Grove",\n        "price": 650000,\n        "bedrooms": 4,\n        "bathrooms": 3,\n        "house_size": 2500,\n        "description": "Step into this modern 4-bedroom, 3-bathroom home located in the sought-after Maple Grove neighborhood. The open floor plan is perfect for entertaining, with a gourmet kitchen featuring stainless steel appliances and a spacious island. Relax in the luxurious master suite with a walk-in closet and a spa-like bathroom. The backyard oasis is ideal for summer BBQs and gatherings. Experience suburban luxury at its finest in Maple Grove.",\n        "neighborhood_description": "Maple Grove offers a family-friendly environment with top-rated schools, parks, and local shops. Enjoy a scenic walk around Maple Grove Lake or indulge in shopping at the nearby Maple Mall. This neighborhood provides a perfect blend of tranquility and urban convenience."\n    },\n    {\n        "neighborhood": "Riverside Heights",\n        "price": 950000,\n        "bedrooms": 5,\n        "bathrooms": 4,\n        "house_size": 3500,\n        "description": "Luxury living awaits in this 5-bedroom, 4-bathroom home nestled in the prestigious Riverside Heights neighborhood. High-end finishes and designer touches adorn every corner of this spacious property. The chef\'s kitchen is equipped with top-of-the-line appliances and a large island. The expansive backyard features a sparkling pool and a covered patio, perfect for outdoor relaxation. Experience the epitome of elegance in Riverside Heights.",\n        "neighborhood_description": "Riverside Heights is known for its upscale living and exclusive amenities. Explore the nearby Riverside Plaza for fine dining and boutique shopping, or take a leisurely walk along the Riverside Trail. This neighborhood offers a sophisticated lifestyle with convenient access to major highways and entertainment venues."\n    },\n    {\n        "neighborhood": "Sunnyvale Meadows",\n        "price": 720000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2100,\n        "description": "Welcome to this charming 3-bedroom, 2-bathroom home in the desirable Sunnyvale Meadows neighborhood. The bright and airy living spaces feature vaulted ceilings, skylights, and a cozy fireplace. The updated kitchen boasts granite countertops and stainless steel appliances. Step outside to the landscaped backyard with a deck, perfect for hosting summer gatherings. Enjoy a peaceful lifestyle in Sunnyvale Meadows.",\n        "neighborhood_description": "Sunnyvale Meadows offers a tranquil setting with tree-lined streets and well-maintained parks. Residents can enjoy community events like farmers markets and outdoor concerts. Conveniently located near schools and shopping centers, this neighborhood provides a perfect balance of serenity and convenience."\n    },\n    {\n        "neighborhood ...

# %%
# Remove potential json markdown from listing
listing_json = response.content.strip('` \n')

if listing_json.startswith('json'):
    listing_json = listing_json[4:]

listing_json
# Out:
# '\n[\n    {\n        "neighborhood": "Green Oaks",\n        "price": 800000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2000,\n        "description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.",\n        "neighborhood_description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."\n    },\n    {\n        "neighborhood": "Maple Grove",\n        "price": 650000,\n        "bedrooms": 4,\n        "bathrooms": 3,\n        "house_size": 2500,\n        "description": "Step into this modern 4-bedroom, 3-bathroom home located in the sought-after Maple Grove neighborhood. The open floor plan is perfect for entertaining, with a gourmet kitchen featuring stainless steel appliances and a spacious island. Relax in the luxurious master suite with a walk-in closet and a spa-like bathroom. The backyard oasis is ideal for summer BBQs and gatherings. Experience suburban luxury at its finest in Maple Grove.",\n        "neighborhood_description": "Maple Grove offers a family-friendly environment with top-rated schools, parks, and local shops. Enjoy a scenic walk around Maple Grove Lake or indulge in shopping at the nearby Maple Mall. This neighborhood provides a perfect blend of tranquility and urban convenience."\n    },\n    {\n        "neighborhood": "Riverside Heights",\n        "price": 950000,\n        "bedrooms": 5,\n        "bathrooms": 4,\n        "house_size": 3500,\n        "description": "Luxury living awaits in this 5-bedroom, 4-bathroom home nestled in the prestigious Riverside Heights neighborhood. High-end finishes and designer touches adorn every corner of this spacious property. The chef\'s kitchen is equipped with top-of-the-line appliances and a large island. The expansive backyard features a sparkling pool and a covered patio, perfect for outdoor relaxation. Experience the epitome of elegance in Riverside Heights.",\n        "neighborhood_description": "Riverside Heights is known for its upscale living and exclusive amenities. Explore the nearby Riverside Plaza for fine dining and boutique shopping, or take a leisurely walk along the Riverside Trail. This neighborhood offers a sophisticated lifestyle with convenient access to major highways and entertainment venues."\n    },\n    {\n        "neighborhood": "Sunnyvale Meadows",\n        "price": 720000,\n        "bedrooms": 3,\n        "bathrooms": 2,\n        "house_size": 2100,\n        "description": "Welcome to this charming 3-bedroom, 2-bathroom home in the desirable Sunnyvale Meadows neighborhood. The bright and airy living spaces feature vaulted ceilings, skylights, and a cozy fireplace. The updated kitchen boasts granite countertops and stainless steel appliances. Step outside to the landscaped backyard with a deck, perfect for hosting summer gatherings. Enjoy a peaceful lifestyle in Sunnyvale Meadows.",\n        "neighborhood_description": "Sunnyvale Meadows offers a tranquil setting with tree-lined streets and well-maintained parks. Residents can enjoy community events like farmers markets and outdoor concerts. Conveniently located near schools and shopping centers, this neighborhood provides a perfect balance of serenity and convenience."\n    },\n    {\n        "neighborhood": "Pine Valley",\n       ...

# %%
# Write listings as JSON to file
f = open('listings.json', 'w')
f.write(listing_json.strip())
f.close()

# %% [markdown]
# # Step 3: Storing Listings in a Vector Database

# %%
func = get_registry().get("openai").create(base_url=os.getenv('OPENAI_API_BASE'))

class ListingVector(LanceModel):
    neighborhood: str
    price: int
    bedrooms: int
    bathrooms: int
    house_size: int
    description: str = func.SourceField()
    description_vector: Vector(func.ndims()) = func.VectorField()

# %%
# Read listings from file
df = pd.read_json("listings.json")
df
# Out:
#             neighborhood   price  bedrooms  bathrooms  house_size  \
# 0             Green Oaks  800000         3          2        2000
# 1            Maple Grove  650000         4          3        2500
# 2      Riverside Heights  950000         5          4        3500
# 3      Sunnyvale Meadows  720000         3          2        2100
# 4            Pine Valley  550000         4          3        2200
# 5             Harbor Bay  880000         4          3        2800
# 6    Meadowbrook Heights  680000         3          2        1900
# 7           Golden Hills  750000         4          3        2300
# 8      Lakefront Estates  920000         5          4        3200
# 9  Mountain View Terrace  690000         3          2        2000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Step into this modern 4-bedroom, 3-bathroom ho...
# 2  Luxury living awaits in this 5-bedroom, 4-bath...
# 3  Welcome to this charming 3-bedroom, 2-bathroom...
# 4  Discover this lovely 4-bedroom, 3-bathroom hom...
# 5  Live the coastal lifestyle in this stunning 4-...
# 6  Step into this charming 3-bedroom, 2-bathroom ...
# 7  Welcome to this beautiful 4-bedroom, 3-bathroo...
# 8  Indulge in luxury living in this expansive 5-b...
# 9  Discover this cozy 3-bedroom, 2-bathroom home ...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Maple Grove offers a family-friendly environme...
# 2  Riverside Heights is known for its upscale liv...
# 3  Sunnyvale Meadows offers a tranquil setting wi...
# 4  Pine Valley exudes a peaceful ambiance with sc...
# 5  Harbor Bay offers a resort-style living experi...
# 6  Meadowbrook Heights is a nature lover's paradi...
# 7  Golden Hills offers a prestigious lifestyle wi...
# 8  Lakefront Estates is known for its upscale pro...
# 9  Mountain View Terrace provides a serene settin...

# %%
# Write listings to database

vector_data = df.apply(lambda listing: {
    "neighborhood": listing["neighborhood"],
    "price": listing["price"],
    "bedrooms": listing["bedrooms"],
    "bathrooms": listing["bathrooms"],
    "house_size": listing["house_size"],
    "description": listing["description"] + " " + listing["neighborhood_description"]
}, axis=1).values.tolist()

table = vector_db.create_table('listings', mode='overwrite', exist_ok=True, schema=ListingVector)
table.add(vector_data)

table.to_pandas()
# Out:
#             neighborhood   price  bedrooms  bathrooms  house_size  \
# 0             Green Oaks  800000         3          2        2000
# 1            Maple Grove  650000         4          3        2500
# 2      Riverside Heights  950000         5          4        3500
# 3      Sunnyvale Meadows  720000         3          2        2100
# 4            Pine Valley  550000         4          3        2200
# 5             Harbor Bay  880000         4          3        2800
# 6    Meadowbrook Heights  680000         3          2        1900
# 7           Golden Hills  750000         4          3        2300
# 8      Lakefront Estates  920000         5          4        3200
# 9  Mountain View Terrace  690000         3          2        2000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Step into this modern 4-bedroom, 3-bathroom ho...
# 2  Luxury living awaits in this 5-bedroom, 4-bath...
# 3  Welcome to this charming 3-bedroom, 2-bathroom...
# 4  Discover this lovely 4-bedroom, 3-bathroom hom...
# 5  Live the coastal lifestyle in this stunning 4-...
# 6  Step into this charming 3-bedroom, 2-bathroom ...
# 7  Welcome to this beautiful 4-bedroom, 3-bathroo...
# 8  Indulge in luxury living in this expansive 5-b...
# 9  Discover this cozy 3-bedroom, 2-bathroom home ...
#
#                                   description_vector
# 0  [0.012680263, -0.000397279, 0.0059024305, -0.0...
# 1  [0.013225698, 0.016146159, -0.008484774, -0.02...
# 2  [0.015028327, 0.021495543, -0.0016582182, -0.0...
# 3  [0.009319344, 0.013159768, 0.009921636, -0.012...
# 4  [0.030138627, 0.010957135, 0.00087188603, -0.0...
# 5  [0.009495488, -0.00065554626, 0.011885914, -0....
# 6  [0.0025294574, 0.001907299, -0.003006282, -0.0...
# 7  [0.024445431, 0.020198612, 0.00418456, -0.0215...
# 8  [0.009897441, 0.017221548, -0.0070997644, -0.0...
# 9  [0.01838561, 0.012598514, -0.0054445677, -0.01...

# %% [markdown]
# # Step 4: Building the User Preference Interface

# %%
# Example
questions = [   
    "How big do you want your house to be?",
    "What are 3 most important things for you in choosing this property?", 
    "Which amenities would you like?", 
    "Which transportation options are important to you?",
    "How urban do you want your neighborhood to be?",   
]
answers = [
    "A comfortable three-bedroom house with a spacious kitchen and a cozy living room.",
    "A quiet neighborhood, good local schools, and convenient shopping options.",
    "A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system.",
    "Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads.",
    "A balance between suburban tranquility and access to urban amenities like restaurants and theaters."
]

qa_messages = []
qa_messages.append(("system", f"""
    You are a real estate preference retrieving chat bot.
    You are asking users {len(questions)} questions and they respond to it.
    
    After the last question process the given preferences and return a JSON object with keys and values containing the preferences.
    If there are concrete numbers given return them as integer field in the object, e.g. number of bedrooms = 2.
"""))

for i in range(len(questions)):
    qa_messages.append(("ai", questions[i]))
    
    # If INTERACTIVE is true, ask the user his preferences.
    if INTERACTIVE:
        qa_messages.append(("human", input(questions[i] + "\n")))
    else:
        qa_messages.append(("human", answers[i]))

qa_response = llm.invoke(qa_messages)

# %%
# Remove potential JSON markdown from response
user_preferences = qa_response.content.strip('` \n')

if user_preferences.startswith('json'):
    user_preferences = user_preferences[4:]

print(user_preferences)
# Out:
# {
#     "HouseSize": "Three-bedroom",
#     "KitchenSize": "Spacious",
#     "LivingRoomSize": "Cozy",
#     "Neighborhood": {
#         "Quiet": true,
#         "GoodSchools": true,
#         "ConvenientShopping": true
#     },
#     "Amenities": {
#         "Backyard": true,
#         "GarageSize": "Two-car",
#         "HeatingSystem": "Modern and energy-efficient"
#     },
#     "Transportation": {
#         "BusLine": true,
#         "ProximityToHighway": true,
#         "BikeFriendly": true
#     },
#     "UrbanFactor": "Balanced suburban tranquility with access to urban amenities"
# }

# %% [markdown]
# # Step 5: Searching Based on Preferences

# %%
# Search for the 3 best matches of listings to user preferences
search_result = table.search(user_preferences).limit(3).to_pydantic(ListingVector)

search_result
# Out:
# [ListingVector(neighborhood='Meadowbrook Heights', price=680000, bedrooms=3, bathrooms=2, house_size=1900, description="Step into this charming 3-bedroom, 2-bathroom home in the peaceful Meadowbrook Heights neighborhood. The inviting living room features a brick fireplace and a bay window with garden views. The updated kitchen is equipped with quartz countertops and a breakfast nook. Retreat to the backyard oasis with a deck and mature trees, offering a private and serene escape. Enjoy a relaxed lifestyle in Meadowbrook Heights. Meadowbrook Heights is a nature lover's paradise with walking trails, parks, and nature reserves just steps away. Residents can unwind in the community pool or enjoy a picnic in the neighborhood park. With easy access to shopping centers and schools, this neighborhood provides a mix of tranquility and convenience.", description_vector=FixedSizeList(dim=1536)),
#  ListingVector(neighborhood='Golden Hills', price=750000, bedrooms=4, bathrooms=3, house_size=2300, description="Welcome to this beautiful 4-bedroom, 3-bathroom home in the sought-after Golden Hills neighborhood. The light-filled interiors showcase a blend of modern and traditional design with high ceilings and elegant finishes. The chef's kitchen features quartz countertops and a center island. Relax in the spacious master suite with a luxurious en suite bathroom. Step outside to the landscaped backyard with a pergola and fire pit, perfect for outdoor gatherings. Experience upscale living in Golden Hills. Golden Hills offers a prestigious lifestyle with upscale boutiques, gourmet restaurants, and cultural attractions. Residents can enjoy a round of golf at the nearby country club or take a scenic drive along the Golden Hills Parkway. This neighborhood provides a perfect combination of luxury and convenience.", description_vector=FixedSizeList(dim=1536)),
#  ListingVector(neighborhood='Maple Grove', price=650000, bedrooms=4, bathrooms=3, house_size=2500, description='Step into this modern 4-bedroom, 3-bathroom home located in the sought-after Maple Grove neighborhood. The open floor plan is perfect for entertaining, with a gourmet kitchen featuring stainless steel appliances and a spacious island. Relax in the luxurious master suite with a walk-in closet and a spa-like bathroom. The backyard oasis is ideal for summer BBQs and gatherings. Experience suburban luxury at its finest in Maple Grove. Maple Grove offers a family-friendly environment with top-rated schools, parks, and local shops. Enjoy a scenic walk around Maple Grove Lake or indulge in shopping at the nearby Maple Mall. This neighborhood provides a perfect blend of tranquility and urban convenience.', description_vector=FixedSizeList(dim=1536))]

# %% [markdown]
# # Step 6: Personalizing Listing Descriptions

# %%
# Create personalized listing descriptions for the found listing.
PROMPT_TEMPLATE = """
Take the following Listing:

{listing}

---

Rewrite this real estate listing to highlight aspects relevant to the buyer preferences: {user_preferences}.
"""

personalized_listings = []
for listing in search_result:
    prompt = PromptTemplate.from_template(PROMPT_TEMPLATE).format(user_preferences=user_preferences,listing=listing.description)
    personalized_listing = listing.model_copy()
    personalized_listing.description = llm.invoke(prompt).content
    personalized_listings.append(personalized_listing)

personalized_listings

pd.DataFrame([listing.model_dump() for listing in personalized_listings])
# Out:
#           neighborhood   price  bedrooms  bathrooms  house_size  \
# 0  Meadowbrook Heights  680000         3          2        1900
# 1         Golden Hills  750000         4          3        2300
# 2          Maple Grove  650000         4          3        2500
#
#                                          description  \
# 0  Discover this spacious three-bedroom home in a...
# 1  Welcome to this charming three-bedroom, two-ba...
# 2  Step into this cozy three-bedroom home in the ...
#
#                                   description_vector
# 0  [0.0025294574443250895, 0.0019072990398854017,...
# 1  [0.0244454313069582, 0.020198611542582512, 0.0...
# 2  [0.013225697912275791, 0.016146158799529076, -...
